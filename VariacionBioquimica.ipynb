# %% [markdown]
# <a href="https://colab.research.google.com/github/EgiNHardo/Proyecto0/blob/main/VariacionBioquimica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 🧪 Código 2: Cuadro gráfico de variación bioquímica

# %%
# Instala dependencias si es necesario
# !pip install pandas seaborn matplotlib

# %%
# Importar librerías
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Instala dependencias si es necesario
#   !pip install pandas seaborn matplotlib

# Importar librerías
#   import pandas as pd
#   import seaborn as sns
#   import matplotlib.pyplot as plt

# Datos simulados
data = {
    "Estructura cerebral": ["Hipocampo", "Amígdala", "Corteza prefrontal", "Ínsula", "ACC"],
    "Cortisol": [-20, 10, -15, -5, -10],
    "Serotonina": [-15, -5, -10, -5, -5],
    "Dopamina": [-10, 5, -10, 0, -5],
    "Noradrenalina": [-10, 5, -5, 0, -5]
}

df = pd.DataFrame(data)
df_melt = df.melt(id_vars="Estructura cerebral", var_name="Neuroquímico", value_name="Variación (%)")

# Crear gráfico
plt.figure(figsize=(12, 6))
sns.barplot(data=df_melt, x="Estructura cerebral", y="Variación (%)", hue="Neuroquímico", palette="viridis")
plt.title("Variación de compuestos bioquímicos por estructura cerebral (efectos del estrés crónico)", fontsize=13)
plt.axhline(0, color='gray', linestyle='--')
plt.legend(title="Neuroquímico")
plt.xticks(rotation=0)
plt.tight_layout()
plt.savefig("variacion_bioquimica_cerebro.png", dpi=300, bbox_inches='tight')  # Guardar imagen
plt.show()

# %% [markdown]
# 📥 Descargar imagen del gráfico bioquímico

# %%
from google.colab import files
files.download("variacion_bioquimica_cerebro.png")
