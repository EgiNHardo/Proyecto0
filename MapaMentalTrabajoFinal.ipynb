# %% [markdown]
# <a href="https://colab.research.google.com/github/EgiNHardo/Proyecto0/blob/main/MapaMentalTrabajoFinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 🧠 Código 1: Mapa Mental de la Etiología y Manifestaciones

# %%
# Instala dependencias si es necesario
# !pip install networkx matplotlib

# %%
# Importar librerías
import matplotlib.pyplot as plt
import networkx as nx

# %%
# Instala dependencias si es necesario
#   !pip install networkx matplotlib

# Importar librerías
#   import matplotlib.pyplot as plt
#   import networkx as nx

# Crear el grafo del mapa mental
G = nx.Graph()

# Nodo central
G.add_node("Gestión emocional en educación superior")

# Subnodos principales
subnodes = [
    "Neurobiología de las emociones",
    "Factores psicosociales",
    "Manifestaciones clínicas",
    "Consecuencias académicas y personales"
]

for node in subnodes:
    G.add_node(node)
    G.add_edge("Gestión emocional en educación superior", node)

# Subnodos de neurobiología
neuro_nodes = [
    "Sistema límbico: amígdala, hipocampo, ínsula",
    "Corteza prefrontal: regulación emocional",
    "Eje HPA: estrés crónico, cortisol elevado",
    "Atrofia cortical y neuroinflamación"
]
for node in neuro_nodes:
    G.add_node(node)
    G.add_edge("Neurobiología de las emociones", node)

# Subnodos psicosociales
social_nodes = [
    "Presión académica extrema",
    "Aislamiento institucional",
    "Falta de red de apoyo"
]
for node in social_nodes:
    G.add_node(node)
    G.add_edge("Factores psicosociales", node)

# Subnodos de manifestaciones clínicas
manifest_nodes = [
    "Déficit cognitivo: memoria, atención",
    "Síntomas emocionales: ansiedad, fatiga",
    "Conductas evitativas: procrastinación, abandono"
]
for node in manifest_nodes:
    G.add_node(node)
    G.add_edge("Manifestaciones clínicas", node)

# Subnodos de consecuencias académicas
conseq_nodes = [
    "Desmotivación profunda",
    "Retiro del posgrado",
    "Fracaso académico"
]
for node in conseq_nodes:
    G.add_node(node)
    G.add_edge("Consecuencias académicas y personales", node)

# Posiciones y graficado
pos = nx.spring_layout(G, k=0.9, seed=42)
plt.figure(figsize=(15, 10))
nx.draw(G, pos, with_labels=True, node_size=3000, node_color="lightblue", font_size=9, font_weight="bold")
plt.title("Mapa mental: Etiología y manifestaciones de los desórdenes emocionales en el posgrado", fontsize=14)
plt.axis("off")
plt.savefig("mapa_mental_emociones.png", dpi=300, bbox_inches='tight')  # Guardar imagen
plt.show()

# %% [markdown]
# 📥 Descargar imagen del mapa mental

# %%
from google.colab import files
files.download("mapa_mental_emociones.png")
